# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("subscription_dataset.csv")
df
# Out:
#       CustomerID TransactionID        Date                  Description  \
# 0             C1            T1  2025-01-01                Salary Credit
# 1             C1            T2  2025-01-02   Payment to Cafe Coffee Day
# 2             C1            T3  2025-01-02     Payment to Medical Store
# 3             C1            T4  2025-01-03              Payment to Uber
# 4             C1            T5  2025-01-04  Gym Membership Subscription
# ...          ...           ...         ...                          ...
# 98712       C500        T98713  2025-06-25            Payment to Swiggy
# 98713       C500        T98714  2025-06-25              Payment to Uber
# 98714       C500        T98715  2025-06-27       Payment to Petrol Pump
# 98715       C500        T98716  2025-06-27   Payment to Cafe Coffee Day
# 98716       C500        T98717  2025-06-28              Payment to Uber
#
#               Merchant  Amount  Balance  SubscriptionFlag
# ...
