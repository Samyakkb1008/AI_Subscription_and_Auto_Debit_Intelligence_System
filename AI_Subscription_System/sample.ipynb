# %%
import pandas as pd

# %%
df = pd.read_csv("data\\processed\\final_transactions.csv")
df
# Out:
#       CustomerID TransactionID        Date                 Description  \
# 0             C1            T2  2025-01-02  payment to cafe coffee day
# 1             C1            T7  2025-01-05  payment to cafe coffee day
# 2             C1            T9  2025-01-06  payment to cafe coffee day
# 3             C1           T17  2025-01-14  payment to cafe coffee day
# 4             C1           T60  2025-02-20  payment to cafe coffee day
# ...          ...           ...         ...                         ...
# 95319        C99        T19590  2025-05-10           payment to zomato
# 95320        C99        T19592  2025-05-12           payment to zomato
# 95321        C99        T19601  2025-05-23           payment to zomato
# 95322        C99        T19604  2025-05-27           payment to zomato
# 95323        C99        T19627  2025-06-17           payment to zomato
#
#               Merchant  Amount  Balance  SubscriptionFlag  Transaction_Type  \
# ...

# %%
df["Frequency"].value_counts()
# Out:
# Frequency
# Weekly           65175
# Irregular        23221
# Monthly           6902
# Not Recurring       26
# Name: count, dtype: int64

# %%
df[df["Frequency"] != "Not Recurring"]
# Out:
#       CustomerID TransactionID        Date                 Description  \
# 0             C1            T2  2025-01-02  payment to cafe coffee day
# 1             C1            T7  2025-01-05  payment to cafe coffee day
# 2             C1            T9  2025-01-06  payment to cafe coffee day
# 3             C1           T17  2025-01-14  payment to cafe coffee day
# 4             C1           T60  2025-02-20  payment to cafe coffee day
# ...          ...           ...         ...                         ...
# 95319        C99        T19590  2025-05-10           payment to zomato
# 95320        C99        T19592  2025-05-12           payment to zomato
# 95321        C99        T19601  2025-05-23           payment to zomato
# 95322        C99        T19604  2025-05-27           payment to zomato
# 95323        C99        T19627  2025-06-17           payment to zomato
#
#               Merchant  Amount  Balance  SubscriptionFlag  Transaction_Type  \
# ...

# %%
risk_df = pd.read_csv("outputs\\risk_scoring_output.csv")

# %%
risk_df["Risk_Level"].value_counts()
# Out:
# Risk_Level
# Low     4233
# High       7
# Name: count, dtype: int64
