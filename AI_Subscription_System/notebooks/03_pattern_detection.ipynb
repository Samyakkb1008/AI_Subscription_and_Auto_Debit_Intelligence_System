# %% [markdown]
# # Pattern Detection
#
# ## Objective
# To identify recurring transactions and determine their frequency (weekly, monthly) based on transaction history.

# %%
import pandas as pd
# Out:
# Running cells with 'venv_Py3.12 (3.13.12) (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/admin/OneDrive/Desktop/JOB/OPUS/Training_Assessment/GroupTask1_Mansi_Samyak/AI_Subscription_and_Auto_Debit_Intelligence_System/Group_Project_AI_Subscription_and_Auto_Debit_Intelligence_System/venv_Py3.12/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
